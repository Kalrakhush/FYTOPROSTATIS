# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle

# %%
dataset = pd.read_csv('peerj-cs-07-687-s001.csv')
dataset
# Out:
#                Location            Address              Period  \
# 0     Karjat, MH, India  Karjat, MH, India   Week 1 (Jan) 2000
# 1     Karjat, MH, India  Karjat, MH, India   Week 2 (Jan) 2000
# 2     Karjat, MH, India  Karjat, MH, India   Week 3 (Jan) 2000
# 3     Karjat, MH, India  Karjat, MH, India   Week 4 (Jan) 2000
# 4     Karjat, MH, India  Karjat, MH, India   Week 5 (Jan) 2000
# ...                 ...                ...                 ...
# 1637  Karjat, MH, India  Karjat, MH, India  Week 49 (Dec) 1989
# 1638  Karjat, MH, India  Karjat, MH, India  Week 50 (Dec) 1989
# 1639  Karjat, MH, India  Karjat, MH, India  Week 51 (Dec) 1989
# 1640  Karjat, MH, India  Karjat, MH, India  Week 52 (Dec) 1989
# 1641  Karjat, MH, India  Karjat, MH, India   Week 1 (Dec) 1989
#
#       Maximum Temperature  Minimum Temperature  Temperature  Heat Index  \
# 0                    33.1                 17.5         25.4        32.3
# 1                    33.1                 11.2         24.8        32.0
# 2                    31.1                 11.2         24.3        31.9
# 3                    37.1                 17.2         26.3        39.4
# 4                    34.1                 17.3         25.9        32.8
# ...                   ...                  ...          ...         ...
# 1637                 32.1                 14.2         24.2        31.0
# 1638                 34.1                 15.1         23.7        32.8
# 1639                 33.2                 13.9         22.9        31.5
# 1640                 30.1                 14.9         22.4        29.0
# 1641                 29.4                 15.7         22.6        30.1
#
#       Precipitation  Wind Speed  Cloud Cover  Relative Humidity  Unnamed: 11  \
# 0               0.0        14.8          0.3              48.93          NaN
# 1               0.0        18.4          2.4              42.30          NaN
# 2               0.0        22.3          5.5              57.20          NaN
# 3               0.0        22.3          7.6              53.69          NaN
# 4               0.0        18.4          1.1              44.75          NaN
# ...             ...         ...          ...                ...          ...
# 1637            0.0        14.8          3.5              57.38          NaN
# 1638            0.0        11.2          6.8              53.15          NaN
# 1639            0.0        10.6         12.2              53.12          NaN
# 1640            0.0        12.3         21.4              59.59          NaN
# 1641            0.2        12.3         49.1              62.23          NaN
#
#        Disease
# 0     Stem Rot
# 1        Blast
# 2        Blast
# 3     Stem Rot
# 4     Stem Rot
# ...        ...
# 1637     Blast
# 1638     Blast
# 1639     Blast
# 1640     Blast
# 1641     Blast
#
# [1642 rows x 13 columns]

# %%
dataset.head()
# Out:
#             Location            Address             Period  \
# 0  Karjat, MH, India  Karjat, MH, India  Week 1 (Jan) 2000
# 1  Karjat, MH, India  Karjat, MH, India  Week 2 (Jan) 2000
# 2  Karjat, MH, India  Karjat, MH, India  Week 3 (Jan) 2000
# 3  Karjat, MH, India  Karjat, MH, India  Week 4 (Jan) 2000
# 4  Karjat, MH, India  Karjat, MH, India  Week 5 (Jan) 2000
#
#    Maximum Temperature  Minimum Temperature  Temperature  Heat Index  \
# 0                 33.1                 17.5         25.4        32.3
# 1                 33.1                 11.2         24.8        32.0
# 2                 31.1                 11.2         24.3        31.9
# 3                 37.1                 17.2         26.3        39.4
# 4                 34.1                 17.3         25.9        32.8
#
#    Precipitation  Wind Speed  Cloud Cover  Relative Humidity  Unnamed: 11  \
# 0            0.0        14.8          0.3              48.93          NaN
# 1            0.0        18.4          2.4              42.30          NaN
# 2            0.0        22.3          5.5              57.20          NaN
# 3            0.0        22.3          7.6              53.69          NaN
# 4            0.0        18.4          1.1              44.75          NaN
#
#     Disease
# 0  Stem Rot
# 1     Blast
# 2     Blast
# 3  Stem Rot
# 4  Stem Rot

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()

# %%
filename = "peerj-cs-07-687-s001.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Shape of your Data Set loaded: (1642, 13)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  8
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  3
#     13 Predictors classified...
#         3 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 36
# All Plots done
# Time to run AutoViz = 10 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
features_with_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1]

for feature in features_with_na:
    print(feature, np.round(dataset[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# Unnamed: 11 1.0  % missing values

# %%
df=dataset.drop(['Location','Address','Period','Unnamed: 11','Precipitation','Maximum Temperature','Minimum Temperature'],axis=1)
df
# Out:
#       Temperature  Heat Index  Wind Speed  Cloud Cover  Relative Humidity  \
# 0            25.4        32.3        14.8          0.3              48.93
# 1            24.8        32.0        18.4          2.4              42.30
# 2            24.3        31.9        22.3          5.5              57.20
# 3            26.3        39.4        22.3          7.6              53.69
# 4            25.9        32.8        18.4          1.1              44.75
# ...           ...         ...         ...          ...                ...
# 1637         24.2        31.0        14.8          3.5              57.38
# 1638         23.7        32.8        11.2          6.8              53.15
# 1639         22.9        31.5        10.6         12.2              53.12
# 1640         22.4        29.0        12.3         21.4              59.59
# 1641         22.6        30.1        12.3         49.1              62.23
#
#        Disease
# 0     Stem Rot
# 1        Blast
# 2        Blast
# 3     Stem Rot
# 4     Stem Rot
# ...        ...
# 1637     Blast
# 1638     Blast
# 1639     Blast
# 1640     Blast
# 1641     Blast
#
# [1642 rows x 6 columns]

# %%
dataset.dtypes
# Out:
# Location                object
# Address                 object
# Period                  object
# Maximum Temperature    float64
# Minimum Temperature    float64
# Temperature            float64
# Heat Index             float64
# Precipitation          float64
# Wind Speed             float64
# Cloud Cover            float64
# Relative Humidity      float64
# Unnamed: 11            float64
# Disease                 object
# dtype: object

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df[50:100]
# Out:
#     Temperature  Heat Index  Wind Speed  Cloud Cover  Relative Humidity  \
# 50         24.6        33.0        16.6          8.6              56.56
# 51         25.0        34.1        14.8          7.2              55.36
# 52         24.7        33.8        20.5         34.2              57.75
# 53         24.1        33.5        20.5         20.7              64.99
# 54         23.6        30.5        16.6         13.1              63.21
# 55         25.4        33.1        22.3         23.9              59.31
# 56         22.1        29.9        18.4         19.5              57.74
# 57         23.6        30.5        18.4         36.7              55.83
# 58         22.9        34.5        18.4          3.5              56.79
# 59         22.8        31.2        18.4          5.3              63.16
# 60         25.3        34.7        18.4          7.2              65.71
# 61         25.8        33.8        20.5         26.9              65.76
# 62         25.8        35.0        22.3         27.1              63.82
# 63         25.5        33.0        22.3         19.7              67.23
# 64         26.1        34.7        22.3         20.7              68.34
# 65         25.7        33.6        24.1         17.1              56.35
# 66         28.6        39.9        22.3         29.3              59.06
# 67         28.4        37.8        24.1         40.2              61.01
# 68         28.9        42.0        27.7         30.5              63.55
# 69         28.8        38.1        25.9         18.0              67.03
# 70         29.3        40.7        25.9         35.1              69.56
# 71         28.9        38.0        74.2         35.7              70.66
# 72         29.5        39.4        27.7         41.0              70.70
# 73         30.1        43.7        33.5         53.2              64.70
# 74         29.2        40.7        31.3         56.4              72.12
# 75         28.3        39.4        25.9         69.8              78.70
# 76         26.5        35.6        33.5         91.0              79.87
# 77         28.1        37.0        27.7         72.0              72.16
# 78         28.2        35.9        33.5         63.7              70.30
# 79         26.1        36.3        29.5         91.6              81.81
# 80         25.9        35.2        33.5         88.9              81.87
# 81         27.1        35.6        29.5         87.8              75.47
# 82         27.4        36.7        25.9         77.3              76.93
# 83         26.9        36.7        27.7         81.9              77.32
# 84         27.0        36.7        29.5         92.2              78.38
# 85         27.2        36.9        31.3         89.9              77.04
# 86         27.7        36.9        22.3         85.6              74.48
# 87         27.9        36.9        27.7         74.5              72.40
# 88         27.8        39.5        18.4         66.2              73.57
# 89         27.9        39.3        27.7         60.5              72.21
# 90         26.9        40.7        27.7         79.0              80.66
# 91         27.9        44.0        27.7         66.7              79.00
# 92         27.3        39.3        27.7         73.8              83.44
# 93         27.6        43.7        24.1         61.2              82.79
# 94         28.9        45.9        20.5         45.6              70.35
# 95         28.8        37.9        18.4          2.9              52.68
# 96         27.8        44.0        18.4          6.4              64.58
# 97         27.3        38.4        69.8          7.7              57.33
# 98         27.6        44.0        79.6         10.2              60.51
# 99         28.2        46.9        14.8          5.6              47.46
#
#        Disease
# 50       Blast
# 51    Stem Rot
# 52       Blast
# 53       Blast
# 54       Blast
# 55    Stem Rot
# 56       Blast
# 57       Blast
# 58       Blast
# 59       Blast
# 60    Stem Rot
# 61    Stem Rot
# 62    Stem Rot
# 63    Stem Rot
# 64    Stem Rot
# 65    Stem Rot
# 66    Stem Rot
# 67    Stem Rot
# 68    Stem Rot
# 69    Stem Rot
# 70    Stem Rot
# 71    Stem Rot
# 72    Stem Rot
# 73  False Smut
# 74    Stem Rot
# 75    Stem Rot
# 76    Stem Rot
# 77    Stem Rot
# 78    Stem Rot
# 79    Stem Rot
# 80    Stem Rot
# 81    Stem Rot
# 82    Stem Rot
# 83    Stem Rot
# 84    Stem Rot
# 85    Stem Rot
# 86    Stem Rot
# 87    Stem Rot
# 88    Stem Rot
# 89    Stem Rot
# 90    Stem Rot
# 91    Stem Rot
# 92    Stem Rot
# 93    Stem Rot
# 94    Stem Rot
# 95    Stem Rot
# 96    Stem Rot
# 97    Stem Rot
# 98    Stem Rot
# 99    Stem Rot

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
X
# Out:
# array([[25.4 , 32.3 , 14.8 ,  0.3 , 48.93],
#        [24.8 , 32.  , 18.4 ,  2.4 , 42.3 ],
#        [24.3 , 31.9 , 22.3 ,  5.5 , 57.2 ],
#        ...,
#        [22.9 , 31.5 , 10.6 , 12.2 , 53.12],
#        [22.4 , 29.  , 12.3 , 21.4 , 59.59],
#        [22.6 , 30.1 , 12.3 , 49.1 , 62.23]])

# %% [markdown]
# ### y

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
y[73]
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_test
# Out:
# array([[24.4 , 32.3 , 18.4 , 22.4 , 51.07],
#        [26.7 , 32.7 , 29.  , 12.9 , 55.93],
#        [29.7 , 38.  , 19.7 ,  8.9 , 56.66],
#        ...,
#        [29.  , 42.5 , 20.5 , 31.4 , 64.77],
#        [26.4 , 37.2 , 65.6 , 31.4 , 68.44],
#        [27.6 , 38.1 , 18.4 , 81.3 , 80.36]])

# %%
X_train
# Out:
# array([[24.5 , 30.6 , 24.1 , 21.5 , 42.99],
#        [27.9 , 35.4 , 24.1 , 21.8 , 58.12],
#        [28.8 , 35.6 , 21.  , 49.9 , 67.92],
#        ...,
#        [27.  , 34.3 , 18.4 , 68.5 , 77.2 ],
#        [28.3 , 37.8 , 29.5 , 78.6 , 65.96],
#        [23.6 , 35.3 , 14.8 ,  1.2 , 57.67]])

# %%
y_train
# Out:
# array([0, 3, 3, ..., 3, 3, 0])

# %%
y_test
# Out:
# array([0, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 0, 3,
#        3, 0, 0, 0, 2, 3, 1, 3, 3, 3, 3, 0, 3, 3, 0, 0, 3, 0, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0, 2, 0, 3, 2, 0, 3, 2, 2, 3, 3, 3,
#        0, 3, 3, 3, 3, 3, 0, 3, 3, 3, 0, 0, 0, 0, 0, 3, 3, 3, 3, 3, 3, 3,
#        0, 3, 3, 0, 3, 0, 3, 3, 0, 3, 3, 3, 3, 0, 0, 0, 3, 3, 0, 0, 0, 2,
#        3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 2, 3, 3, 0, 3,
#        3, 2, 3, 3, 2, 0, 3, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 2, 3, 0, 3,
#        1, 3, 3, 0, 3, 0, 3, 0, 3, 2, 3, 3, 3, 3, 0, 0, 3, 3, 3, 3, 0, 0,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 0, 0, 3, 0, 3, 3, 0, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 0,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 0, 3, 3,
#        0, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 2, 3, 0, 0, 3, 3, 3, 3, 3, 3])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, [0,1,2,3,4]] = sc.fit_transform(X_train[:,[0,1,2,3,4] ])
X_test[:,  [0,1,2,3,4]] = sc.transform(X_test[:,  [0,1,2,3,4]])

# %%
X_train
# Out:
# array([[-1.1061163 , -1.54749621,  0.15704563, -0.63720524, -1.9227699 ],
#        [ 0.38493796, -0.36759564,  0.15704563, -0.62738624, -0.70610794],
#        [ 0.77962879, -0.31843312, -0.14431821,  0.2923264 ,  0.08194805],
#        ...,
#        [-0.00975287, -0.63798952, -0.39707497,  0.90110416,  0.82818882],
#        [ 0.5603561 ,  0.22235464,  0.68200199,  1.23167703, -0.07566315],
#        [-1.50080713, -0.3921769 , -0.74704588, -1.30162398, -0.74229419]])

# %%
X_test
# Out:
# array([[-1.14997083, -1.12961476, -0.39707497, -0.60774825, -1.27302577],
#        [-0.14131649, -1.03128971,  0.63339492, -0.91868313, -0.88221433],
#        [ 1.17431962,  0.27151717, -0.27069659, -1.04960308, -0.8235122 ],
#        ...,
#        [ 0.86733786,  1.37767395, -0.19292528, -0.31317837, -0.17135566],
#        [-0.2728801 ,  0.07486707,  4.19143249, -0.31317837,  0.12376326],
#        [ 0.25337435,  0.29609843, -0.39707497,  1.32004799,  1.08229668]])

# %%
X_train
# Out:
# array([[-1.1061163 , -1.54749621,  0.15704563, -0.63720524, -1.9227699 ],
#        [ 0.38493796, -0.36759564,  0.15704563, -0.62738624, -0.70610794],
#        [ 0.77962879, -0.31843312, -0.14431821,  0.2923264 ,  0.08194805],
#        ...,
#        [-0.00975287, -0.63798952, -0.39707497,  0.90110416,  0.82818882],
#        [ 0.5603561 ,  0.22235464,  0.68200199,  1.23167703, -0.07566315],
#        [-1.50080713, -0.3921769 , -0.74704588, -1.30162398, -0.74229419]])

# %%
X_test
# Out:
# array([[-1.14997083, -1.12961476, -0.39707497, -0.60774825, -1.27302577],
#        [-0.14131649, -1.03128971,  0.63339492, -0.91868313, -0.88221433],
#        [ 1.17431962,  0.27151717, -0.27069659, -1.04960308, -0.8235122 ],
#        ...,
#        [ 0.86733786,  1.37767395, -0.19292528, -0.31317837, -0.17135566],
#        [-0.2728801 ,  0.07486707,  4.19143249, -0.31317837,  0.12376326],
#        [ 0.25337435,  0.29609843, -0.39707497,  1.32004799,  1.08229668]])

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
df
# Out:
#       Temperature  Heat Index  Wind Speed  Cloud Cover  Relative Humidity  \
# 0            25.4        32.3        14.8          0.3              48.93
# 1            24.8        32.0        18.4          2.4              42.30
# 2            24.3        31.9        22.3          5.5              57.20
# 3            26.3        39.4        22.3          7.6              53.69
# 4            25.9        32.8        18.4          1.1              44.75
# ...           ...         ...         ...          ...                ...
# 1637         24.2        31.0        14.8          3.5              57.38
# 1638         23.7        32.8        11.2          6.8              53.15
# 1639         22.9        31.5        10.6         12.2              53.12
# 1640         22.4        29.0        12.3         21.4              59.59
# 1641         22.6        30.1        12.3         49.1              62.23
#
#        Disease
# 0     Stem Rot
# 1        Blast
# 2        Blast
# 3     Stem Rot
# 4     Stem Rot
# ...        ...
# 1637     Blast
# 1638     Blast
# 1639     Blast
# 1640     Blast
# 1641     Blast
#
# [1642 rows x 6 columns]

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred)), y_test.reshape(len(y_test)))))
# Out:
# [0 3 3 3 0 3 3 3 3 3 3 0 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 0 3 3 3 3 0 3
#  3 3 3 3 3 0 3 3 0 0 0 2 3 1 3 3 3 3 0 3 3 0 0 3 0 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 0 2 0 3 2 0 3 3 2 3 3 3 0 3 3 3 3 3 0 3 3 3 0 0 0 0 0 3 3 3 3 3 3 3 0
#  3 3 0 3 0 3 3 0 3 3 3 3 0 0 0 3 3 0 0 0 2 3 3 3 3 2 3 3 3 3 3 2 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 0 3 3 3 3 3 3 3 0 3 3 3 3 3 3 0 3 3 2 3 3 2 0 3 3 3
#  3 0 3 3 3 3 3 3 3 2 3 0 3 0 3 3 0 3 0 3 0 3 2 3 3 3 3 0 0 3 3 3 3 0 0 3 3
#  3 3 3 3 3 3 2 3 3 3 0 3 3 3 3 3 3 3 3 3 3 3 0 3 0 3 3 0 3 3 0 3 3 3 3 3 3
#  3 3 3 2 0 3 3 3 3 3 3 3 3 3 3 0 3 3 3 0 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 0 3
#  3 3 3 3 3 3 3 3 2 0 3 3 0 3 2 2 3 3 3 3 3 2 3 2 3 0 0 3 3 3 3 3 3 0 3 3 3
#  0 3 3 3 3 3 3 0 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 0 3 3 3 3 0 3 3 3 3 3
#  3 0 3 3 0 0 0 2 3 1 3 3 3 3 0 3 3 0 0 3 0 3 3 3 3 3 3 3 3 3 3 3 3 3 3 0 2
#  0 3 2 0 3 2 2 3 3 3 0 3 3 3 3 3 0 3 3 3 0 0 0 0 0 3 3 3 3 3 3 3 0 3 3 0 3
#  0 3 3 0 3 3 3 3 0 0 0 3 3 0 0 0 2 3 3 3 3 2 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 0 3 3 3 3 3 3 3 0 3 3 3 2 3 3 0 3 3 2 3 3 2 0 3 3 3 3 0 3 3
#  3 3 3 3 3 2 3 0 3 1 3 3 0 3 0 3 0 3 2 3 3 3 3 0 0 3 3 3 3 0 0 3 3 3 3 3 3
#  3 3 2 3 3 3 0 3 3 3 3 3 3 3 3 3 3 0 0 3 0 3 3 0 3 3 0 3 3 3 3 3 3 3 3 3 2
#  0 3 3 3 3 3 3 3 3 3 3 0 3 3 3 0 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 0 3 3 3 3 3
#  3 3 3 3 2 0 3 3 0 3 2 2 3 3 3 3 3 2 3 2 3 0 0 3 3 3 3 3 3]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[ 59   0   0   1]
#  [  1   1   0   0]
#  [  0   0  18   2]
#  [  0   0   0 247]]
# 0.9878419452887538

# %%
plt.scatter(y_test,y_pred)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Saving model to disk

# %%
pickle.dump(classifier,open('Plant Diseases.pkl','wb'))

# %%
#Loading the model to compare the results

# %%
Diseases=pickle.load(open('Plant Diseases.pkl','rb'))

# %%
print(Diseases.predict(sc.transform([[24.8,32.0,18.4,2.4,42.30]])))
# Out:
# [0]
